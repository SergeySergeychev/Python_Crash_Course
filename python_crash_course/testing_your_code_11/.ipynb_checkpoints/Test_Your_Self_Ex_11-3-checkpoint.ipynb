# %%
# Try IT YOURSELF
# EX 11-3. Employee:

# Condition:
#    Write a class called Employee.
#    

# Task:
#    Create class employee.The __init__() method should take 
#    first name, last name and annual salary.
#    Write a method called give_raise() that adds money to annual salary.
#    
# Test: 
#    
#    

# Solution:    
    #  Create class Employee()
    #  Write what class represents.
    #  Create first method __init__()
    #  Write what __init__ method represents.
    #  Put inside of init method tree parametres(f_name, l_name, salary)
    #  All parametres write as attributes .self.
    #  Create second method give_raise()
    #  Write what give_raise() method represents.
    #  Put inside of give_raise one parametre (???)
    #  Create variable  
    #  ...
    # 
    # 
    
# Code of mine.

class Employee():
    """A simple attempt to represent life of an employee."""
    
    def __init__(self, f_name, l_name,annual_salary):
        """Initialize attributes to describe employee"""
        self.f_name = f_name
        self.l_name = l_name
        self.annual_salary = annual_salary 
        
    def give_raise(self, custom_raise=0):
        """A simple attempt to represent raising of an annual salary"""
        default_raise = 5000
        self.annual_salary+=salary_raise + default_raise
        print("Congrtulations, your salary now is " + 
              str(self.annual_salary) + "$"
             )
employee = Employee('sergey','sergeychev',20000)
employee.give_raise()
employee.annual_salary

# %%
import unittest

from usual_employee import Employee

class EmployeeTestCase(unittest.TestCase):
    """Test for 'usual_employee.py'."""
    
    def test_give_default_raise(self):
        """Does default salary raise works?"""
        employee = Employee('sergey', 'sergeychv', 20000)
        default_raise= employee.give_raise()
        self.assertEqual(employee.annual_salary, 25000)
        
    def test_give_custom_raise(self):
        "Does custom salary raise works?"
        employee = Employee('sergey', 'sergeychev', 20000)
        custom_raise = employee.give_raise(5000)
        self.assertEqual(employee.annual_salary, 30000)
        
if __name__ == '__main__':
    unittest.main(argv=['first-arg-is-ignored'], exit=False)

# %%
import unittest

from usual_employee import Employee

class EmployeeTestCase(unittest.TestCase):
    """A simple attempt to represent employee"""
    
    def setUp(self):
        """Create an employee and a set of salaries."""
        self.employee = Employee('sergey', 'sergeychev', 20000)
        self.employee.annual_salary
        self.annual_salary_with_d_r = 25000
        self.annual_salary_with_c_r = 30000
        
    def test_give_custom_raise(self):
        """Does custom salary raise works?"""
        self.employee.give_raise(5000)
        self.assertEqual(self.employee.annual_salary, self.annual_salary_with_c_r)
    
    def test_give_dafault_raise(self):
        """Does default salary raise works?"""
        self.employee.give_raise()
        self.assertEqual(self.employee.annual_salary, self.annual_salary_with_d_r)
        
if __name__ == '__main__':
    unittest.main(argv=['first-arg-is-ignored'], exit=False)

# %%
# CODE by ehmatthes.github.io

import unittest

from employee import Employee

class TestEmployee(unittest.TestCase):
    """Tests for the module employee."""
    
    def setUp(self):
        """Make an employee to use in tests."""
        self.eric = Employee('eric', 'matthes', 65_000)
        
    def test_give_default_raise(self):
        """Test thatt a default raise works correctly."""
        self.eric.give_raise()
        self.assertEqual(self.eric.salary, 70000)
        
    def test_give_custom_raise(self):
        """Test that a custom raise works correctly."""
        self.eric.give_raise(10000)
        self.assertEqual(self.eric.salary, 75000)
        
if __name__ == '__main__':
    unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# ..
# ----------------------------------------------------------------------
# Ran 2 tests in 0.009s
#
# OK
