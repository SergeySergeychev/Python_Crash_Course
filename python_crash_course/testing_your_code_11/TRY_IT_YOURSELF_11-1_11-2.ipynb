# %%
# Try IT YOURSELF
# EX 11-1. City, Country:

# Condition:
#    Write a function that returns: a city name and a country name.
#    Run unittest.function to check function modify_city_country

# Task:
#    Write a function that accepts  two parameters:a city name and a country name.
#    The function should return a single string of the form 'City, Country'
#    Test the function with unittest to verify that calling function with value such as
#    'santiago' and 'chile result is 'City, Country'.

# Test: 
#    Test function modify_city_country(city_name, country_name)
#    Make sure test_city_country(passes)

# Solution:    
    # Write function get_city_country with two parametres(city, country)
    # Create variable city_country and assign it with string "city country"
    # Return variable city_country with upper case.
    # Run function modify_city_country with arguments ('riga', 'latvia').
    # Store the function in a module city_function.py.
    # impport unittest .
    # Import modify_city_country from module city_function.py.
    # Write method called test_city_county()
    # Create variable city_country_titled = modify_city_country('riga', 'latvia')
    # Use unittests method .assertEqual(variable, comparable sentence)
    # Run unittest and make sure test_city_country() passes.
    
# Code of mine.

import unittest
from city_functions import modify_city_country

class CityCountryTestCase(unittest.TestCase):
    """Tests for 'city_functions.py'."""
    
    def test_city_country(self):
        """Do names of a country and a city are titled."""
        city_country_titled = modify_city_country('riga', 'latvia') 
        self.assertEqual(city_country_titled, 'Riga, Latvia')
        
if __name__ == '__main__':
    unittest.main(argv=['first-arg-is-ignored'], exit=False)

# %%
# Code from ehmatthes.github.io

import unittest

from city_functions import get_city_country

class CitiesTestCase(unittest.TestCase):
    """Test for 'city_functions.py'."""
    
    def test_city_country(self):
        """Does a simple city and country pair work?"""
        santiago_chile = get_city_country('santiago', 'chile')
        self.assertEqual(santiago_chile, 'Santiago, Chile')
        
if __name__ == '__main__':
    unittest.main(argv=['first-arg-is-ignored'], exit=False)

# %%
# Try IT YOURSELF
# EX 11-2. City, Country:

# Condition:
#    Modify function so it requires a third paramaters, population 
#    Modify function so the population parameter is optional.
#    Write second test test_city_country_population.

# Task:
#    Modify function in city_functions.py and add a third parameter
#    Test function with a third parameter it must to fail.
#    Modify function in city_functions.py and make a third parameter optional
#    Test function with an optional parameter it must pass.
#    Write a second test test_city_country_population().


# Test: 
#    Test function with a third parameter .
#    Test function with an third optional parameter.
#    Test function with new testing condition. 

# Solution:    
    # Add third parameter a population to function modify_city_country.
    # Create variable city_country_population = City, Country - population xxx
    # Return variable city_country_population in correct form.
    # Run function modify_city_country with arguments ('riga', 'latvia' '- population').
    # Store the function in a module city_function.py.
    # impport unittest .
    # Import modify_city_country from module city_function.py.
    # Write method called test_city_county()
    # Create variable city_country_titled = modify_city_country('riga', 'latvia')
    # Use unittests method .assertEqual(variable, comparable sentence)
    # Run unittest and make sure test_city_country() fails.
    # Add to function modify_city_country positional parameter population.
    # Write if statement.If parameter population  has been added as argument 
    # to function modify_city_country, return tree arguments ->
    # -> Else return only city and country arguments 
    # Run unittest and make sure test_city_country passes.
    # Write second test_city_country_population()
    # Create variable c_c_population = modify_city_country (city, country, population)
    # Use unittest method .assertEqual (variable, comparable sentence)
    # Run unittest and make sure both tests passes

# %%
#EX 11-2. Population.
# Code of mine.

import unittest 

from city_functions import modify_city_country

class CityCountryTestCase(unittest.TestCase):
    """Tests for 'city_functions.py'."""
    def test_city_country(self):
        """Does city and country pair work?"""
        city_country_titled = modify_city_country('riga', 'latvia')
        self.assertEqual(city_country_titled, 'Riga, Latvia')
    
    def test_city_country_population(self):
        """Does city, country, population pair work?"""
        c_c_population = modify_city_country('riga', 'latvia', '- population 5000000')
        self.assertEqual(c_c_population, 'Riga, Latvia - population 5000000')
        
if __name__ == '__main__':
    unittest.main(argv=['first-arg-is-ignored'], exit=False)

# %%
# EX 11-2

# Code from ehmatthes.github.io

import unittest

from city_country_eh import city_country

class CitiesTestCase(unittest.TestCase):
    """Tests for 'city_functions_eh.py'."""
    
    def test_city_country(self):
        """Does a simple city and country pair work?"""
        santiago_chile = city_country('santiago', 'chile')
        self.assertEqual(santiago_chile, 'Santiago, Chile')
        
    def test_city_country_population(self):
        """Can i include a population argument?"""
        santiago_chile = city_country('santiago', 'chile', population=5000000)
        self.assertEqual(santiago_chile, 'Santiago, Chile - population 5000000')
        
if __name__ == '__main__':
    unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# ..
# ----------------------------------------------------------------------
# Ran 2 tests in 0.009s
#
# OK
